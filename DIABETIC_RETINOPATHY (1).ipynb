# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.7.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)

# %%
# !mkdir -p ~/.kaggle
# !mv /content/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d arbethi/diabetic-retinopathy-level-detection
# Out:
# Dataset URL: https://www.kaggle.com/datasets/arbethi/diabetic-retinopathy-level-detection
# License(s): CC0-1.0
# Downloading diabetic-retinopathy-level-detection.zip to /content
# 100% 9.63G/9.66G [01:08<00:00, 181MB/s]
# 100% 9.66G/9.66G [01:08<00:00, 151MB/s]

# %%
# !unzip /content/diabetic-retinopathy-level-detection.zip -d "/content/drive/My Drive/dataset"
# Out:
# Archive:  /content/diabetic-retinopathy-level-detection.zip
#   inflating: /content/drive/My Drive/dataset/inception-diabetic.h5
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/cfb17a7cc8d4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/cfdbaef73a8b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/cfed7c1172ec.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/cff262ed8f4c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/cffc50047828.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d02b79fc3200.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d0926ed2c8e5.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d160ebef4117.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d16e39b9d6f0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d16e59a2b33a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d18f6431ebce.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d1a60c3b9fe5.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d1afdb8cf70d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d1b279cc02ae.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d1ca85af57c9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d1cf31577a59.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d1f7ea924a01.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d1fa0f744620.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d26bb2ed6e71.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d26bc6e1230d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d27ac9e54901.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d29b37d110f3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d2afca74cbc3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d2c5fb82fe5f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d2cd47ed2c1d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d2d523e9f669.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d2dc86021c67.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d2fb715b0c41.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d30d079e6f9a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d332d7b8a26e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d38cf0f4a9af.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d39752cb6e57.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d3dfd0a2dee6.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d3e56584a481.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d436c06f0490.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d4583e9525dc.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d4bc001f7224.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d516f77d4516.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d51c2153d151.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d51e5d7484ea.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d56d32a1d62d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d57d1be1bbd1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d5ad3362424c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d5c63a8d9e94.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d6130f2ec903.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d667af5742f6.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d6803e467592.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d69698f838db.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d6b109c82067.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d6dbb0820ea5.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d6df4fe492ec.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d6f36ec5564a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d6f6bdfd8011.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d7078e8b0349.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d74ccc796517.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d774692d9919.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d78b7401096f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d7a01fca9838.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d7ab5c040294.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d7ac4a0c9760.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d7bc00091cfc.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d7bc62d60e8c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d7e5fe5245e0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d807c53c1399.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d838d5b9f571.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d844a7252f4e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d865997a6280.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d866c26d76f0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d871895742b1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d881c04f01fe.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d88c4843aec3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d8da9de62743.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d911dd40c63b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d91635f380b4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d93b61dc8f64.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d97911a32918.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d99b0f7dd9b9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d99dd99be001.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d9ad2a0ec026.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d9c9b9786da3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d9d2631f043c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d9e58e4d8689.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/da0a83f074f3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/da2bdf4236ac.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/da3a2275c850.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/da6389d129aa.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/da6bbb76d562.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/da9262d9f5d9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/da949aa67a4f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/da9574d35b82.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/da9fe02dead3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/daad7b617f21.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/daff5427c9b2.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/db3cd58aa315.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/db52626d450c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/db6207e62c7b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dc0eea0b68a7.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dc0f6e5b489b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dcc6c0ad5cad.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dccdf750c962.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dce73d90c00c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dcf109df1a2b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dd02d60bef14.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dd285d9e97fe.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dd3176bacfe2.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dd90c321d7bc.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ddb222ff7c1d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/de18071c36e6.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/de2eb5c8aa83.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/de38adaae009.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/de4cdabbce6d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/de55ed25e0e8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/de57c9e9fa93.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/de6210f88536.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/de730033c683.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dea7538bb91a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dec5595e6154.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dee1031a76ae.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dee31065f8fe.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/df0886f1e76b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/df6d13d04da1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/df9cb3729eb1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dfc7ec7db0e0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/dfea19863428.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e01b7bac822b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e0313be77035.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e03a74e7d74f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e04f3c6619a3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e067b06fd655.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e06cccc08c59.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e087bd4b88f2.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e0d229db881a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e12df54e0d1e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e12f9f19d1be.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e135d7ba9a0e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e160a3b19911.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e16af45285e5.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e1ab92228e60.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e1b8acb1cea1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e1c02f6c3362.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e1dc02a3dc2a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e2265c383348.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e246cd89e1cc.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e251bdf05b85.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e26bcae6c67b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e29e54ff921e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e2c39ed0c941.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e2c3b037413b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e2ec22b3d07e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e30a890600e1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e322acd46152.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e33766353db2.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e3b47ed5b511.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e3cd96cb094c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e42d9a94a66d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e47452069ea1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e47770a2e5d1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e4a44f9158dc.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e4ae1ee6aada.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e4b0df29b96f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e4c799738a19.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e4d3d437b0a8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e4dcca36ceb4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e50b0174690d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e5197d77ec68.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e529c5757d64.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e582e56e7942.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e594c19e2e1d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e59c5f345bb0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e5de79795c1d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e5f332efcbc7.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e5f73f2855c0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e60e4edb3ca9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e632e38fd2d4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e6552b7432b3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e66855a5c583.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e66ad813a508.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e68746d426b2.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e68bdd36e589.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e69b48516577.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e6a5e4718873.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e7291472109b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e7578d8dba72.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e77a93c3d9a9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e79e10907295.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e7b5dd5bab1f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e81f4a2fbbdc.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e82232a3c28b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e893e86dde94.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e8ddfc9709ce.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e8e44b3160e3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e907d23cce3d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e933923aab15.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e966850247f4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e9678824215d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e97ecf4355cb.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e9ce5bf645ab.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e9f3c85a2a02.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/e9faf0296643.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ea4ce9516144.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ea5c42a78979.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ea68b58a6e8f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ea6a53e54d0f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ea7e21bab610.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ea9c41e1ced0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/eabc7c716255.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/eabf421f94d0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/eae70f527755.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/eb050765b323.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/eb175669d789.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/eb6b1f1c09db.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ebd96d853918.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ebf4b22240f4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ec01f0862669.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ec0c9f817b03.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ec363f48867b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ec57cc20d776.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ec6659926105.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ec6f1797a25a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ecad6845f630.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ecb4500285ed.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ed2c52c14493.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ed2ef440d22c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ed3ce1674761.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ed648b9bcd95.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ed6bd9293a89.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/eda1d75cbcf0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/eda29a9d78f3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/edceb0657d77.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ee36ca728641.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ee3f5cf52188.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ee3fe7809e6a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ee77763a6afb.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/eeaea2c5ff34.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/eebd1e195952.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/eedae6b28f96.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ef247f28004f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ef4121e9bb67.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ef476be214d4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ef48780f5d5f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ef5155990874.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ef7eb85b75fc.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ef81cd8854cb.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ef8c39eb9157.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ef99c499d665.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f002ce614c59.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f00ce9b9d6f4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f02057c41256.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f0267c42907c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f02956bd7c50.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f02babb3a023.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f0546a45ef10.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f066db7a2efe.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f06e7a9df795.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f0860c21533b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f09cfc6a4dbd.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f09fd9433dff.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f0a2dc580009.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f0e1201b5c1f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f1979147aad4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f1d719c97838.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f233638e0e90.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f252046c0fe6.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f26b02ead915.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f298b7d05958.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f2c0b41acd05.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f2f569a64949.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f35d80bb1a22.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f361060eda3e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f366fb1cc475.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f36cb007a1ef.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f3a4751af42e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f3b27ac2d371.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f3bb996b45ce.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f42b693a9414.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f431f2e119d7.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f451eee2b66b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f48241b0c995.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f4874247ede6.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f4c7ae514c54.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f4d3169b468a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f4de9620e3f2.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f4df3d86688d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f4e68b61f480.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f4ea2a2cfbb9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f531232ecb55.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f56ff0440ed1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f5733f77273d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f57cf3b6f48e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f580566e27f5.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f58cdfa968be.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f58f0b2fd718.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f5c953bee7cd.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f62b8a076833.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f633c474e8b8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f64b6e85f1c9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f66c4ee86629.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f68690db78d3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f6d760566a51.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f7116e7b2f4e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f71333204618.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f71aca5a7dc3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f71bea807c96.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f7508f14dd7b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f7735b6d47f7.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f7defe70afc3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f7e9fa75c7c1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f819c65b803c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f85c78201a50.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f85fd4fac887.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f86d1c404acb.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f8d62557ad0c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f8f5942b690e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f90f8931a9bc.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f91cfa82b9d4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f952ad2e4356.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f994a3b07935.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f9d52509c571.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f9d8ff3e6592.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/f9e1c439d4c8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fa0c87bd75ce.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fa573163dd8b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fa6f3d8bb1d5.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fa7fa797c650.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fa9bece586fc.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fa9f1bc03f21.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fb1b8771c70a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fb767cea406c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fb88783de055.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fb88d23fc5fe.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fbcbc81cf9be.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fbdc796290d4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fbfa925506f6.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fc782722a50c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fc898dfeb24f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fc8fce67fbf8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fca1a8738b8a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fcc32dffd24d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fce73678f650.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fd079d2e93a2.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fd0a70082e7c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fd4c946c52bf.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fd87b6b2e664.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fdbc252813b1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fdc685055659.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fe06dad6851c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fe0e2dee1834.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fe3b0e50be78.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fe3f62695b2d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/febfb20dc311.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fed5bb685832.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/fefded6bf135.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ff03f74667df.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ff1e940105f9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ff4832d55461.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ff4955e76894.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ff4cd992667b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ff59d44a70a7.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ff631653374e.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ffc04fed30e6.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/0/ffd97f8cd5aa.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/c0968d41eb93.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/c102db7634d8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/c40976189f22.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/c739ff9580d3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/c9485c38fdd5.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/ca1036496659.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/ca25745942b0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/ca30a97e9d13.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/ca63fe4f4b52.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/ca6842bfcbc9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/ca7140ecf389.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/cab3dfa7962d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/cae51154e1ce.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/cb2f3c5d71a7.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/cc12453ea915.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/cc9270f06b65.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/cd45bfa07d41.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/cd5714db652d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/cf0575534cec.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/cf603a9ef2d5.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/cfd1bd0fcbb4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d06ccd0cf4b8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d0d59ed675b5.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d1cad012a254.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d3de0d313d61.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d4f32b9c07df.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d567a1a22d33.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d5b4705ac2ee.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d66b6f333dc7.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d66ccb75ada1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d6e26fe51dce.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d801c0a66738.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d85588ff2ebd.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/d85d052900b4.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/da1fb35f5df9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/db4ed1e07aa3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/db690e2d02f8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/dbd062558b81.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/dd19428c3d29.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/e07045d7c5f7.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/e25ccfe38e44.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/e26d8718ca58.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/e2a233493b90.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/e38f3a65b02b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/e55188915f9d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/e580676516b0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/e9286ddf6ffe.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/e96bd80a8a53.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/e9ff9352ccb3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/ea15a290eb96.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/testing/1/ead23cc922ed.png
# ...
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/85cbb84ac8e0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/873dcc0b468f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/875a2fc5fe23.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/87774aafe068.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8785b71238d8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/887c26fc0e1f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8ac0c44bbf24.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8ae049175db6.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8af6a4e5396f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8bad12d70368.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8bed09514c3b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8c7c26c52a6c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8d8aca52c07b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8db2ce991101.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8eeac97f02f0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8f318a978844.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/8fd7ad26e691.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/905cc86bf100.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/94ef1d14597f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/95e732e043a1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/97da093947e8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/9859e2a6cc24.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/9a496b1e20f9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/9c72ed6befa0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/9cc6b1f9bcbd.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/9e3510963315.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/9fab29e69a6b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/a0cd7bffdaa0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/a11bf2edd470.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/a182b5b191de.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/a2ddabee14e9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/a32b5ce3d48a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/a3fcf42ff56d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/a5c9a8c726b2.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/a6d45de20e4d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/a76b69e443ce.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/a81b06f50612.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/aa6673241154.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/ab1c20a94f3f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/aeed1f251ceb.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/b1b3e7d0a5f3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/b37aae3c8fe1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/b3819a805dca.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/b49b2fac2514.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/b55d2ddb3e75.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/b70cb31b9abb.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/b77b8a1f09f1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/b87f9c59748b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/b90bc89ce8d8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/b96b518596b3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/b99afe7137fb.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/ba08cee68c71.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/ba4d2c4b3039.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/ba735b286d62.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/bba38f2294a3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/bc34ed91c9bc.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/bcd503c726ba.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/bd5013540a13.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/bd9904495ccd.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/bdff5d8bddf8.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/bfdee9be1f1d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/bfefa7344e7d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/c01eae4b4939.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/c0e509786f7f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/c1799a6f5c65.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/c1896142a20a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/c3d12a23f451.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/c5e238aa18be.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/c62585bd68fb.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/c6a145742708.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/c8d2d32f7f29.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/cb547e723a16.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/cbd0870aa933.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/cc3d2e961768.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/cd54d022e37d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/cd93a472e5cd.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/cd972e5639e0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/cf1b9d26d38d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d0b132d2c7ec.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d10ef306996b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d1a24527a15d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d271d3a2b552.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d2901144070c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d2c2f02bb313.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d48178e4a49b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d51b3fe0fa1b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d659d7fd5ccf.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d803598dabda.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d85ea1220a03.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/d9ba044671e1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/dad71ba27a9b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/de16416220de.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/df4913ca3712.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/df4aec4a0eaf.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/df84e7113003.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e019b3e0f33d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e037643244b7.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e23add229074.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e32dc722eca5.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e39b627cf648.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e3ab63dc9a60.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e3ec668f6fad.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e4730ddde408.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e4f12411fd85.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e62490b7d0e9.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e740af6ac6ea.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e7d2c2c3b30f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e821c1b6417a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/e9ab8413e771.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/eaa0dfbd5024.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/eadc57064154.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/eb1d37b71fd1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/ebe0175e530c.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/ed246ae1ed08.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/ed3a0fc5b546.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/ee1ec90b980f.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/ef26625121b3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f0098e9d4aee.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f025f33b2c9b.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f03d3c4ce7fb.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f0f89314e860.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f1dc26c4bfa3.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f2d2a0c92034.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f549294e12e1.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f58d37d48e42.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f5e6226bd2e0.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f69835dc7c50.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f6f3ea0d2693.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f72adcac5638.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f850cb51fdba.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/f8cf7ed8ef00.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/fa59221cf464.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/fb696a8e055a.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/fce93caa4758.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/fdd534271f3d.png
#   inflating: /content/drive/My Drive/dataset/preprocessed dataset/preprocessed dataset/training/4/ff8a0b45c789.png

# %%
import os

# Define the paths to your training and validation directories
train_dir = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/training'
val_dir = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/testing'

# Function to count the number of images in each class
def count_images_per_class(directory):
    class_counts = {}
    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if os.path.isdir(class_path):
            num_images = len(os.listdir(class_path))
            class_counts[class_name] = num_images
    return class_counts

# Count the images in the training and validation directories
train_counts = count_images_per_class(train_dir)
val_counts = count_images_per_class(val_dir)

print("Number of images per class in the training set:")
for class_name, num_images in train_counts.items():
    print(f"{class_name}: {num_images}")

print("\nNumber of images per class in the validation set:")
for class_name, num_images in val_counts.items():
    print(f"{class_name}: {num_images}")
# Out:
# Number of images per class in the training set:
# 0: 1805
# 1: 370
# 2: 999
# 3: 193
# 4: 295
#
# Number of images per class in the validation set:
# 0: 361
# 1: 74
# 2: 200
# 3: 39
# 4: 60

# %%
import os
import matplotlib.pyplot as plt

# Define the paths to your training directory
train_dir = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/training'

# Define a mapping from class names (folder names) to descriptive labels
class_labels = {
    '0': 'No DR',
    '1': 'Mild DR',
    '2': 'Moderate DR',
    '3': 'Severe DR',
    '4': 'Proliferative DR'
}

# Function to count the number of images in each class
def count_images_per_class(directory):
    class_counts = {}
    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if os.path.isdir(class_path):
            num_images = len(os.listdir(class_path))
            class_counts[class_name] = num_images
    return class_counts

# Count the images in the training directory
train_counts = count_images_per_class(train_dir)

# Map the numerical class names to descriptive labels
train_counts_mapped = {class_labels.get(k, k): v for k, v in train_counts.items()}

# Plotting the bar graph
plt.figure(figsize=(10, 6))
plt.bar(train_counts_mapped.keys(), train_counts_mapped.values(), color='skyblue')
plt.xlabel('Class Names')
plt.ylabel('Number of Images')
plt.title('Number of Images per Class in the Training Set')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Add the class names at the top right
text_str = "\n".join([f"{k}: {v}" for k, v in class_labels.items()])
plt.text(1.05, 1.05, text_str, transform=plt.gca().transAxes, fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))

# Show the plot
plt.show()

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

# Define the path to your training directory
train_dir = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/training'

# Function to resize an image to 224x224
def resize_image(image_path, output_path):
    image = Image.open(image_path)
    resized_image = image.resize((224, 224))
    resized_image.save(output_path)
    return output_path

# Select one image from the training directory
class_name = os.listdir(train_dir)[0]  # Select the first class
image_name = os.listdir(os.path.join(train_dir, class_name))[0]  # Select the first image in the class
image_path = os.path.join(train_dir, class_name, image_name)

# Path to save the resized image
resized_image_path = '/content/resized_image.jpg'

# Resize the image to 224x224 and save it
resized_image_path = resize_image(image_path, resized_image_path)

# Load the images for displaying
original_image = Image.open(image_path)
resized_image = Image.open(resized_image_path)

# Plotting the images side by side
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Display the original image on the left
ax[0].imshow(original_image)
ax[0].axis('off')
ax[0].set_title('Original Image')

# Display the resized image on the right
ax[1].imshow(resized_image)
ax[1].axis('off')
ax[1].set_title('Resized Image (224x224)')

plt.tight_layout()
plt.show()

# %%
import os
from PIL import Image

# Define the path to your training directory
train_dir = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/training'

# Function to resize an image to 224x224 and save it
def resize_and_save_image(image_path, output_path):
    image = Image.open(image_path)
    resized_image = image.resize((224, 224))
    resized_image.save(output_path)  # Save the resized image
    return output_path

# Select one image from the training directory
class_name = os.listdir(train_dir)[0]  # Select the first class
image_name = os.listdir(os.path.join(train_dir, class_name))[0]  # Select the first image in the class
image_path = os.path.join(train_dir, class_name, image_name)

# Path to save the resized image
resized_image_path = '/content/resized_image.jpg'

# Resize the image to 224x224 and save it
resize_and_save_image(image_path, resized_image_path)

print(f"Resized image saved to: {resized_image_path}")
# Out:
# Resized image saved to: /content/resized_image.jpg

# %% [markdown]
# Feature Extraction

# %%
import numpy as np
import os
import cv2
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# Paths to your training and validation directories
train_dir = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/training'
val_dir = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/testing'



datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)

val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d611d11d8815> in <cell line: 1>()
# ----> 1 datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
#       2
#       3 train_generator = datagen.flow_from_directory(
#       4     train_dir,
#       5     target_size=(224, 224),
#
# NameError: name 'ImageDataGenerator' is not defined

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
def extract_features(generator, base_model):
    features_list = []
    labels_list = []

    for inputs_batch, labels_batch in generator:
        features_batch = base_model.predict(inputs_batch)
        features_list.append(features_batch)
        labels_list.append(labels_batch)
        if len(features_list) * generator.batch_size >= generator.samples:
            break

    features = np.concatenate(features_list, axis=0)
    labels = np.concatenate(labels_list, axis=0)
    return features, labels

# %%
# Number of images in the training and validation sets
num_train_images = train_generator.samples
num_val_images = val_generator.samples
print(num_train_images)

# %%
train_features, train_labels = extract_features(train_generator, base_model)

# %%
val_features, val_labels = extract_features(val_generator, base_model)

# %%
train_features = train_features.reshape(len(train_features), -1)
val_features = val_features.reshape(len(val_features), -1)

# One-hot encode the labels
lb = LabelBinarizer()
train_labels = lb.fit_transform(train_labels)
val_labels = lb.transform(val_labels)

# %%
print(train_features.shape)
print(train_labels.shape)
print(val_features.shape)
print(val_labels.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-edaf788e3955> in <cell line: 1>()
# ----> 1 print(train_features.shape)
#       2 print(train_labels.shape)
#       3 print(val_features.shape)
#       4 print(val_labels.shape)
#
# NameError: name 'train_features' is not defined

# %%
# Save the features and labels to disk
np.save('/content/drive/MyDrive/train_features_d3.npy', train_features)
np.save('/content/drive/MyDrive/train_labels_d3.npy', train_labels)
np.save('/content/drive/MyDrive/val_features_d3.npy', val_features)
np.save('/content/drive/MyDrive/val_labels_d3.npy', val_labels)
# # Load the features and labels (if needed)
# train_features_flattened = np.load('train_features.npy')
# train_labels = np.load('train_labels.npy')
# val_features_flattened = np.load('val_features.npy')
# val_labels = np.load('val_labels.npy')

# %%
import numpy as np
train_features = np.load('/content/drive/MyDrive/train_features_d3.npy')
train_labels = np.load('/content/drive/MyDrive/train_labels_d3.npy')
val_features = np.load('/content/drive/MyDrive/val_features_d3.npy')
val_labels = np.load('/content/drive/MyDrive/val_labels_d3.npy')

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import joblib

# %% [markdown]
# optimization algorithm with out feature selection

# %%
train_features = np.load('/content/drive/MyDrive/train_features_d3.npy')
train_labels = np.load('/content/drive/MyDrive/train_labels_d3.npy')
val_features = np.load('/content/drive/MyDrive/val_features_d3.npy')
val_labels = np.load('/content/drive/MyDrive/val_labels_d3.npy')

# %%
# Inside your training code where you fit and transform the training features

# Fit and save the scaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(train_features)
# joblib.dump(scaler, '/content/drive/MyDrive/standard_scaler.pkl')

# Transform the validation features using the fitted scaler
X_val_scaled = scaler.transform(val_features)

# %%
num_classes = train_labels.shape[1]
print(f"Number of classes: {num_classes}")

# Check the shape of the one-hot encoded labels
print(f"Shape of train labels: {train_labels.shape}")
print(f"Shape of validation labels: {val_labels.shape}")
# Out:
# Number of classes: 5
# Shape of train labels: (3662, 5)
# Shape of validation labels: (734, 5)

# %%
train_labels_flat = np.argmax(train_labels, axis=1)  # Assuming train_labels are one-hot encoded
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels_flat), y=train_labels_flat)
class_weights_dict = dict(enumerate(class_weights))

# %%
def cnn_objective_function(params):
    # Extract hyperparameters
    num_neurons1 = int(params[0])
    num_neurons2 = int(params[1])
    learning_rate = params[2]
    dropout_rate = params[3]

    # No feature selection; use all features
    X_train_selected = X_train_scaled
    X_val_selected = X_val_scaled

    # Build and compile the model
    model = Sequential([
        Dense(num_neurons1, activation='relu', input_shape=(X_train_selected.shape[1],)),
        Dropout(dropout_rate),
        Dense(num_neurons2, activation='relu'),
        Dropout(dropout_rate),
        Dense(num_classes, activation='softmax')  # Output layer with num_classes neurons
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss=CategoricalCrossentropy(),
                  metrics=['accuracy'])

    # Train the model
    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    model.fit(X_train_selected, train_labels, epochs=5, batch_size=32, verbose=0, validation_data=(X_val_selected, val_labels), callbacks=[early_stopping],class_weight=class_weights_dict)

    # Evaluate the model
    val_loss, val_accuracy = model.evaluate(X_val_selected, val_labels, verbose=0)
    return -val_accuracy  # Return negative accuracy

# The GWO optimization function remains the same

# %%
def gwo_optimize(obj_function, num_wolves, num_iterations, dim, lower_bound, upper_bound):
    alpha_pos = np.zeros(dim)
    alpha_score = float('inf')

    beta_pos = np.zeros(dim)
    beta_score = float('inf')

    delta_pos = np.zeros(dim)
    delta_score = float('inf')

    wolves_positions = np.random.uniform(lower_bound, upper_bound, (num_wolves, dim))

    for iteration in range(num_iterations):
        for i in range(num_wolves):
            fitness = obj_function(wolves_positions[i])
            if fitness < alpha_score:
                alpha_score = fitness
                alpha_pos = wolves_positions[i].copy()
            elif fitness < beta_score:
                beta_score = fitness
                beta_pos = wolves_positions[i].copy()
            elif fitness < delta_score:
                delta_score = fitness
                delta_pos = wolves_positions[i].copy()

        a = 2 - iteration * (2 / num_iterations)

        for i in range(num_wolves):
            for j in range(dim):
                r1, r2 = np.random.rand(2)
                A1 = 2 * a * r1 - a
                C1 = 2 * r2
                D_alpha = abs(C1 * alpha_pos[j] - wolves_positions[i, j])
                X1 = alpha_pos[j] - A1 * D_alpha

                r1, r2 = np.random.rand(2)
                A2 = 2 * a * r1 - a
                C2 = 2 * r2
                D_beta = abs(C2 * beta_pos[j] - wolves_positions[i, j])
                X2 = beta_pos[j] - A2 * D_beta

                r1, r2 = np.random.rand(2)
                A3 = 2 * a * r1 - a
                C3 = 2 * r2
                D_delta = abs(C3 * delta_pos[j] - wolves_positions[i, j])
                X3 = delta_pos[j] - A3 * D_delta

                wolves_positions[i, j] = (X1 + X2 + X3) / 3
                wolves_positions[i, j] = np.clip(wolves_positions[i, j], lower_bound[j], upper_bound[j])

        print(f"Iteration {iteration+1}/{num_iterations}, Alpha Score: {-alpha_score}")

    return alpha_pos, alpha_score

# %%
num_wolves = 10
num_iterations = 20
dim = 4  # Only hyperparameters, no feature selection
lower_bound = [16, 16, 0.0001, 0.1]
upper_bound = [256, 256, 0.01, 0.5]

best_params, best_score = gwo_optimize(cnn_objective_function, num_wolves, num_iterations, dim, lower_bound, upper_bound)

# Extract the best hyperparameters
num_neurons1 = int(best_params[0])
num_neurons2 = int(best_params[1])
learning_rate = best_params[2]
dropout_rate = best_params[3]

print(f"Best Hyperparameters:")
print(f"Number of neurons in layer 1: {num_neurons1}")
print(f"Number of neurons in layer 2: {num_neurons2}")
print(f"Learning rate: {learning_rate}")
print(f"Dropout rate: {dropout_rate}")

print(f"Best validation score: {-best_score}")
# Out:
# Iteration 1/20, Alpha Score: 0.9495912790298462
# Iteration 2/20, Alpha Score: 0.9495912790298462
# Iteration 3/20, Alpha Score: 0.9604904651641846
# Iteration 4/20, Alpha Score: 0.9822888374328613
# Iteration 5/20, Alpha Score: 0.9850136041641235
# Iteration 6/20, Alpha Score: 0.9877384305000305
# Iteration 7/20, Alpha Score: 0.9904631972312927
# Iteration 8/20, Alpha Score: 0.9904631972312927
# Iteration 9/20, Alpha Score: 0.9904631972312927
# Iteration 10/20, Alpha Score: 0.9918256402015686
# Iteration 11/20, Alpha Score: 0.9918256402015686
# Iteration 12/20, Alpha Score: 0.9918256402015686
# Iteration 13/20, Alpha Score: 0.9918256402015686
# Iteration 14/20, Alpha Score: 0.9931880235671997
# Iteration 15/20, Alpha Score: 0.9931880235671997
# Iteration 16/20, Alpha Score: 0.9931880235671997
# Iteration 17/20, Alpha Score: 0.9931880235671997
# Iteration 18/20, Alpha Score: 0.9931880235671997
# Iteration 19/20, Alpha Score: 0.9931880235671997
# Iteration 20/20, Alpha Score: 0.9931880235671997
# Best Hyperparameters:
# Number of neurons in layer 1: 122
# Number of neurons in layer 2: 66
# Learning rate: 0.000418463017779837
# Dropout rate: 0.1
# Best validation score: 0.9931880235671997

# %%
# Iteration 1/20, Alpha Score: 0.919618546962738
# Iteration 2/20, Alpha Score: 0.9673024415969849
# Iteration 3/20, Alpha Score: 0.9891008138656616
# Iteration 4/20, Alpha Score: 0.9891008138656616
# Iteration 5/20, Alpha Score: 0.9918256402015686
# Iteration 6/20, Alpha Score: 0.9918256402015686
# Iteration 7/20, Alpha Score: 0.9931880235671997
# Iteration 8/20, Alpha Score: 0.9931880235671997
# Iteration 9/20, Alpha Score: 0.9931880235671997
# Iteration 10/20, Alpha Score: 0.9931880235671997
# Iteration 11/20, Alpha Score: 0.9931880235671997
# Iteration 12/20, Alpha Score: 0.9931880235671997
# Iteration 13/20, Alpha Score: 0.9945504069328308
# Iteration 14/20, Alpha Score: 0.9945504069328308
# Iteration 15/20, Alpha Score: 0.9945504069328308
# Iteration 16/20, Alpha Score: 0.9945504069328308
# Iteration 17/20, Alpha Score: 0.9945504069328308
# Iteration 18/20, Alpha Score: 0.9945504069328308
# Iteration 19/20, Alpha Score: 0.9945504069328308
# Iteration 20/20, Alpha Score: 0.9945504069328308
# Best Hyperparameters:
# Number of neurons in layer 1: 150
# Number of neurons in layer 2: 94
# Learning rate: 0.0002917752847222896
# Dropout rate: 0.1202509048409723
# Best validation score: 0.9945504069328308




# Iteration 1/20, Alpha Score: 0.9495912790298462
# Iteration 2/20, Alpha Score: 0.9495912790298462
# Iteration 3/20, Alpha Score: 0.9604904651641846
# Iteration 4/20, Alpha Score: 0.9822888374328613
# Iteration 5/20, Alpha Score: 0.9850136041641235
# Iteration 6/20, Alpha Score: 0.9877384305000305
# Iteration 7/20, Alpha Score: 0.9904631972312927
# Iteration 8/20, Alpha Score: 0.9904631972312927
# Iteration 9/20, Alpha Score: 0.9904631972312927
# Iteration 10/20, Alpha Score: 0.9918256402015686
# Iteration 11/20, Alpha Score: 0.9918256402015686
# Iteration 12/20, Alpha Score: 0.9918256402015686
# Iteration 13/20, Alpha Score: 0.9918256402015686
# Iteration 14/20, Alpha Score: 0.9931880235671997
# Iteration 15/20, Alpha Score: 0.9931880235671997
# Iteration 16/20, Alpha Score: 0.9931880235671997
# Iteration 17/20, Alpha Score: 0.9931880235671997
# Iteration 18/20, Alpha Score: 0.9931880235671997
# Iteration 19/20, Alpha Score: 0.9931880235671997
# Iteration 20/20, Alpha Score: 0.9931880235671997
# Best Hyperparameters:
# Number of neurons in layer 1: 122
# Number of neurons in layer 2: 66
# Learning rate: 0.000418463017779837
# Dropout rate: 0.1
# Best validation score: 0.9931880235671997

# %% [markdown]
# checking with direct images with optimization algorithm features

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

# Parameters
learning_rate = 0.0002917752847222896
dropout_rate = 0.1202509048409723
neurons_layer1 = 150
neurons_layer2 = 94
input_shape = (224, 224, 3)  # Resize images to 224x224, adjust channels if needed
batch_size = 32
num_classes = 5
epochs = 25

# Directories
train_dir = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/training'
val_dir = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/testing'

# Data generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical'  # Use 'categorical' for one-hot encoded labels
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical'
)

# Build the model
model = models.Sequential()
model.add(layers.Input(shape=input_shape))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(neurons_layer1, activation='relu'))
model.add(layers.Dropout(dropout_rate))
model.add(layers.Dense(neurons_layer2, activation='relu'))
model.add(layers.Dropout(dropout_rate))
model.add(layers.Dense(num_classes, activation='softmax'))

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',  # Using categorical cross-entropy
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=val_generator
)

# Evaluate the model
test_loss, test_acc = model.evaluate(val_generator, verbose=2)
print(f"Test accuracy: {test_acc}")

# Save the model
model.save('optimized_cnn_model_2.h5')
# Out:
# Found 3662 images belonging to 5 classes.
# Found 734 images belonging to 5 classes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6736fa6bacbd> in <cell line: 60>()
#      58
#      59 # Train the model
# ---> 60 history = model.fit(
#      61     train_generator,
#      62     epochs=epochs,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     280
#     281         # Create an iterator that yields batches for one epoch.
# --> 282         epoch_iterator = TFEpochIterator(
#     283             x=x,
#     284             y=y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in __init__(self, distribute_strategy, *args, **kwargs)
#     627         super().__init__(*args, **kwargs)
#     628         self._distribute_strategy = distribute_strategy
# --> 629         dataset = self._get_iterator()
#     630         if not isinstance(dataset, tf.distribute.DistributedDataset):
#     631             dataset = self._distribute_strategy.experimental_distribute_dataset(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in _get_iterator(self)
#     636
#     637     def _get_iterator(self):
# --> 638         return self.data_adapter.get_tf_dataset()
#     639
#     640     def enumerate_epoch(self):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py in get_tf_dataset(self)
#     282             if num_batches is not None:
#     283                 num_samples = min(num_samples, num_batches)
# --> 284             batches = [
#     285                 self._standardize_batch(self.py_dataset[i])
#     286                 for i in range(num_samples)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py in <listcomp>(.0)
#     283                 num_samples = min(num_samples, num_batches)
#     284             batches = [
# --> 285                 self._standardize_batch(self.py_dataset[i])
#     286                 for i in range(num_samples)
#     287             ]
#
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py in __getitem__(self, idx)
#      66             self.batch_size * idx : self.batch_size * (idx + 1)
#      67         ]
# ---> 68         return self._get_batches_of_transformed_samples(index_array)
#      69
#      70     def __len__(self):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py in _get_batches_of_transformed_samples(self, index_array)
#     311         filepaths = self.filepaths
#     312         for i, j in enumerate(index_array):
# --> 313             img = image_utils.load_img(
#     314                 filepaths[j],
#     315                 color_mode=self.color_mode,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/image_utils.py in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     234             path = str(path.resolve())
#     235         with open(path, "rb") as f:
# --> 236             img = pil_image.open(io.BytesIO(f.read()))
#     237     else:
#     238         raise TypeError(
#
# KeyboardInterrupt:

# %%
# Found 3662 images belonging to 5 classes.
# Found 734 images belonging to 5 classes.
# Epoch 1/25
# 115/115 [==============================] - 1411s 12s/step - loss: 0.9441 - accuracy: 0.6606 - val_loss: 0.8139 - val_accuracy: 0.7262
# Epoch 2/25
# 115/115 [==============================] - 438s 4s/step - loss: 0.7814 - accuracy: 0.7152 - val_loss: 0.7759 - val_accuracy: 0.7234
# Epoch 3/25
# 115/115 [==============================] - 436s 4s/step - loss: 0.7497 - accuracy: 0.7313 - val_loss: 0.8301 - val_accuracy: 0.7057
# Epoch 4/25
# 115/115 [==============================] - 436s 4s/step - loss: 0.7379 - accuracy: 0.7313 - val_loss: 0.7482 - val_accuracy: 0.7371
# Epoch 5/25
# 115/115 [==============================] - 435s 4s/step - loss: 0.7236 - accuracy: 0.7291 - val_loss: 0.7204 - val_accuracy: 0.7493
# Epoch 6/25
# 115/115 [==============================] - 436s 4s/step - loss: 0.7116 - accuracy: 0.7406 - val_loss: 0.7060 - val_accuracy: 0.7480
# Epoch 7/25
# 115/115 [==============================] - 435s 4s/step - loss: 0.6889 - accuracy: 0.7515 - val_loss: 0.6784 - val_accuracy: 0.7493
# Epoch 8/25
# 115/115 [==============================] - 439s 4s/step - loss: 0.6663 - accuracy: 0.7556 - val_loss: 0.6853 - val_accuracy: 0.7561
# Epoch 9/25
# 115/115 [==============================] - 437s 4s/step - loss: 0.6478 - accuracy: 0.7632 - val_loss: 0.6217 - val_accuracy: 0.7670
# Epoch 10/25
# 115/115 [==============================] - 434s 4s/step - loss: 0.6235 - accuracy: 0.7703 - val_loss: 0.6051 - val_accuracy: 0.7698
# Epoch 11/25
# 115/115 [==============================] - 434s 4s/step - loss: 0.5727 - accuracy: 0.7821 - val_loss: 0.5582 - val_accuracy: 0.7847
# Epoch 12/25
# 115/115 [==============================] - 439s 4s/step - loss: 0.5400 - accuracy: 0.7987 - val_loss: 0.5414 - val_accuracy: 0.7902
# Epoch 13/25
# 115/115 [==============================] - 435s 4s/step - loss: 0.4972 - accuracy: 0.8031 - val_loss: 0.4762 - val_accuracy: 0.8093
# Epoch 14/25
# 115/115 [==============================] - 436s 4s/step - loss: 0.4511 - accuracy: 0.8312 - val_loss: 0.4160 - val_accuracy: 0.8392
# Epoch 15/25
# 115/115 [==============================] - 435s 4s/step - loss: 0.4091 - accuracy: 0.8449 - val_loss: 0.3803 - val_accuracy: 0.8597
# Epoch 16/25
# 115/115 [==============================] - 437s 4s/step - loss: 0.3615 - accuracy: 0.8629 - val_loss: 0.3106 - val_accuracy: 0.8896
# Epoch 17/25
# 115/115 [==============================] - 435s 4s/step - loss: 0.3178 - accuracy: 0.8823 - val_loss: 0.2813 - val_accuracy: 0.8774
# Epoch 18/25
# 115/115 [==============================] - 436s 4s/step - loss: 0.2761 - accuracy: 0.8957 - val_loss: 0.2256 - val_accuracy: 0.9183
# Epoch 19/25
# 115/115 [==============================] - 437s 4s/step - loss: 0.2345 - accuracy: 0.9129 - val_loss: 0.1780 - val_accuracy: 0.9482
# Epoch 20/25
# 115/115 [==============================] - 436s 4s/step - loss: 0.1965 - accuracy: 0.9265 - val_loss: 0.1196 - val_accuracy: 0.9646
# Epoch 21/25
# 115/115 [==============================] - 436s 4s/step - loss: 0.1606 - accuracy: 0.9383 - val_loss: 0.1109 - val_accuracy: 0.9591
# Epoch 22/25
# 115/115 [==============================] - 435s 4s/step - loss: 0.1313 - accuracy: 0.9511 - val_loss: 0.1080 - val_accuracy: 0.9700
# Epoch 23/25
# 115/115 [==============================] - 439s 4s/step - loss: 0.1208 - accuracy: 0.9604 - val_loss: 0.0699 - val_accuracy: 0.9796
# Epoch 24/25
# 115/115 [==============================] - 436s 4s/step - loss: 0.1095 - accuracy: 0.9659 - val_loss: 0.0711 - val_accuracy: 0.9782
# Epoch 25/25
# 115/115 [==============================] - 437s 4s/step - loss: 0.0917 - accuracy: 0.9667 - val_loss: 0.0556 - val_accuracy: 0.9796
# 23/23 - 70s - loss: 0.0556 - accuracy: 0.9796 - 70s/epoch - 3s/step
# Test accuracy: 0.9795640110969543
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import shutil

# Path to the file in Colab
colab_file_path = '/content/optimized_cnn_model_2.h5'

# Destination path in Google Drive
drive_file_path = '/content/drive/MyDrive/optimized_cnn_model_2.h5'

# Copy the file from Colab to Drive
shutil.move(colab_file_path, drive_file_path)

print(f"File moved to {drive_file_path}")
# Out:
# File moved to /content/drive/MyDrive/optimized_cnn_model_2.h5

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# Load the pre-trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/optimized_cnn_model_2.h5')

# Directory for test data
test_dir = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/testing'

# Image dimensions
img_height, img_width = 224, 224

# Prepare the test data generator
test_datagen = ImageDataGenerator(rescale=1./255)  # Normalize images as done during training

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=32,
    class_mode='categorical',
    shuffle=False  # Important to set shuffle=False to match predictions to filenames
)

# Make predictions
predictions = model.predict(test_generator, verbose=1)

# Convert predictions to class labels
predicted_classes = np.argmax(predictions, axis=1)

# Get the true labels
true_classes = test_generator.classes

# Class labels from the generator
class_labels = list(test_generator.class_indices.keys())

# Calculate accuracy, precision, recall, and f1-score
accuracy = accuracy_score(true_classes, predicted_classes)
precision = precision_score(true_classes, predicted_classes, average='weighted')
recall = recall_score(true_classes, predicted_classes, average='weighted')
f1 = f1_score(true_classes, predicted_classes, average='weighted')

print('Accuracy: {:.2f}%'.format(accuracy * 100))
print('Precision: {:.2f}%'.format(precision * 100))
print('Recall: {:.2f}%'.format(recall * 100))
print('F1 Score: {:.2f}%'.format(f1 * 100))

# Print classification report
print('\nClassification Report')
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

# Calculate confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Print confusion matrix in tabular form
print('\nConfusion Matrix (Tabular Form)')
print(cm)

# Calculate the total number of incorrect predictions
total_incorrect = np.sum(cm) - np.trace(cm)
print("\nTotal incorrect predictions:", total_incorrect)

# Plot the confusion matrix as an image
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.show()

# Plot correct vs. wrong predictions
total_predictions = np.sum(cm)
correct_predictions = np.trace(cm)  # Sum of diagonal elements (correct predictions)
wrong_predictions = total_predictions - correct_predictions  # All other elements are wrong predictions

plt.figure(figsize=(8, 6))
plt.bar(['Correct Predictions', 'Wrong Predictions'], [correct_predictions, wrong_predictions], color=['green', 'red'])
plt.title('Correct vs Wrong Predictions')
plt.ylabel('Number of Predictions')
plt.show()

# Note: You cannot plot training and validation metrics as you don't have the training history.
print("Training and validation metrics cannot be plotted as you loaded a pre-trained model. You don't have the training history.")
# Out:
# Found 734 images belonging to 5 classes.
# 23/23 [==============================] - 236s 11s/step
# Accuracy: 97.96%
# Precision: 98.02%
# Recall: 97.96%
# F1 Score: 97.97%
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       361
#            1       0.91      0.99      0.95        74
#            2       0.99      0.96      0.97       200
#            3       0.95      0.92      0.94        39
#            4       0.95      0.97      0.96        60
#
#     accuracy                           0.98       734
#    macro avg       0.96      0.97      0.96       734
# weighted avg       0.98      0.98      0.98       734
#
#
# Confusion Matrix (Tabular Form)
# [[360   1   0   0   0]
#  [  1  73   0   0   0]
#  [  0   5 192   2   1]
#  [  0   0   1  36   2]
#  [  0   1   1   0  58]]
#
# Total incorrect predictions: 15
# Training and validation metrics cannot be plotted as you loaded a pre-trained model. You don't have the training history.

# %%
#predicting the single images
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the model
model = tf.keras.models.load_model('/content/drive/MyDrive/optimized_cnn_model_2.h5')

# Load and preprocess the image
def preprocess_image(img_path, target_size=(224, 224)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array / 255.0  # Normalize to [0, 1] range
    return img_array

# Make a prediction
def predict_image(model, img_path, class_indices):
    img_array = preprocess_image(img_path)
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction, axis=1)[0]
    class_labels = {v: k for k, v in class_indices.items()}
    return class_labels[predicted_class], prediction

# Example usage
img_path = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/testing/2/cd9e2190c73f.png'  # Replace with your image path
class_indices = train_generator.class_indices  # Get the class indices from the training generator
predicted_label, prediction = predict_image(model, img_path, class_indices)

print(f"Predicted label: {predicted_label}")
print(f"Prediction probabilities: {prediction}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# Predicted label: 2
# Prediction probabilities: [[0.01723337 0.15043473 0.75092083 0.00724524 0.07416588]]

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the model
model = tf.keras.models.load_model('/content/drive/MyDrive/optimized_cnn_model_2.h5')
img_path = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/testing/2/cd9e2190c73f.png'  # Replace with your image path
def preprocess_image(img_path, target_size=(224, 224)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array / 255.0  # Normalize to [0, 1] range
    return img_array
def predict_image(model, img_path):
    img_array = preprocess_image(img_path)
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction, axis=1)[0]
    return predicted_class, prediction # Return both predicted class and probabilities

# Predict
predicted_label, prediction = predict_image(model, img_path) # Unpack both returned values

print(f"Predicted label: {predicted_label}")
print(f"Prediction probabilities: {prediction}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Predicted label: 2
# Prediction probabilities: [[0.01723337 0.15043473 0.75092083 0.00724524 0.07416588]]

# %% [markdown]
# checking with the extracted features

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
import pickle
import matplotlib.pyplot as plt

# Assuming train_features, val_features, train_labels, and val_labels are already defined

# Parameters
learning_rate = 0.0002917752847222896
dropout_rate = 0.1202509048409723
neurons_layer1 = 150
neurons_layer2 = 94
num_classes = 5
epochs = 30
batch_size = 32

# Feature Scaling
scaler = StandardScaler()

# Fit and transform the training features
X_train_scaled = scaler.fit_transform(train_features)

# Transform the validation features using the fitted scaler
X_val_scaled = scaler.transform(val_features)

# Save the scaler using joblib or pickle
with open('/content/drive/MyDrive/standard_scaler.pkl', 'wb') as scaler_file:
    pickle.dump(scaler, scaler_file)

# Build the model to train on extracted features
model = models.Sequential()
model.add(layers.Input(shape=X_train_scaled.shape[1:]))
model.add(layers.Flatten())
model.add(layers.Dense(neurons_layer1, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(dropout_rate))  # Increased dropout
model.add(layers.Dense(neurons_layer2, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(dropout_rate))  # Increased dropout
model.add(layers.Dense(num_classes, activation='softmax'))

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model on scaled features
history = model.fit(
    X_train_scaled, train_labels,
    epochs=epochs,
    validation_data=(X_val_scaled, val_labels),
    batch_size=batch_size
)

# Evaluate the model on validation set
test_loss, test_acc = model.evaluate(X_val_scaled, val_labels, verbose=2)
print(f"Test accuracy: {test_acc}")

model.save('/content/drive/MyDrive/optimized_extracted_model_gwo_1.h5')

# Save the model's architecture and weights separately
model_structure = model.to_json()
model_weights = model.get_weights()

# Serialize the architecture and weights using pickle
with open('model_structure.pkl', 'wb') as file:
    pickle.dump(model_structure, file)

with open('model_weights.pkl', 'wb') as file:
    pickle.dump(model_weights, file)

# Plotting training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

# Plotting training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/30
# 115/115 [==============================] - 3s 15ms/step - loss: 1.2152 - accuracy: 0.7245 - val_loss: 0.6569 - val_accuracy: 0.9196
# Epoch 2/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.7019 - accuracy: 0.8960 - val_loss: 0.4868 - val_accuracy: 0.9728
# Epoch 3/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.5472 - accuracy: 0.9522 - val_loss: 0.4402 - val_accuracy: 0.9823
# Epoch 4/30
# 115/115 [==============================] - 1s 13ms/step - loss: 0.4817 - accuracy: 0.9691 - val_loss: 0.4020 - val_accuracy: 0.9837
# Epoch 5/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.4456 - accuracy: 0.9760 - val_loss: 0.3815 - val_accuracy: 0.9877
# Epoch 6/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.4211 - accuracy: 0.9771 - val_loss: 0.3746 - val_accuracy: 0.9891
# Epoch 7/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.4019 - accuracy: 0.9795 - val_loss: 0.3594 - val_accuracy: 0.9891
# Epoch 8/30
# 115/115 [==============================] - 1s 13ms/step - loss: 0.3867 - accuracy: 0.9809 - val_loss: 0.3524 - val_accuracy: 0.9864
# Epoch 9/30
# 115/115 [==============================] - 1s 13ms/step - loss: 0.3816 - accuracy: 0.9806 - val_loss: 0.3473 - val_accuracy: 0.9864
# Epoch 10/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.3675 - accuracy: 0.9820 - val_loss: 0.3419 - val_accuracy: 0.9837
# Epoch 11/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.3590 - accuracy: 0.9839 - val_loss: 0.3376 - val_accuracy: 0.9837
# Epoch 12/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.3427 - accuracy: 0.9836 - val_loss: 0.3194 - val_accuracy: 0.9905
# Epoch 13/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.3431 - accuracy: 0.9812 - val_loss: 0.3093 - val_accuracy: 0.9891
# Epoch 14/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.3229 - accuracy: 0.9831 - val_loss: 0.3083 - val_accuracy: 0.9891
# Epoch 15/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.3230 - accuracy: 0.9831 - val_loss: 0.2925 - val_accuracy: 0.9850
# Epoch 16/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.3182 - accuracy: 0.9798 - val_loss: 0.2894 - val_accuracy: 0.9850
# Epoch 17/30
# 115/115 [==============================] - 1s 13ms/step - loss: 0.3142 - accuracy: 0.9809 - val_loss: 0.2889 - val_accuracy: 0.9850
# Epoch 18/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.3069 - accuracy: 0.9809 - val_loss: 0.2822 - val_accuracy: 0.9809
# Epoch 19/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.3140 - accuracy: 0.9784 - val_loss: 0.2741 - val_accuracy: 0.9918
# Epoch 20/30
# 115/115 [==============================] - 1s 13ms/step - loss: 0.3008 - accuracy: 0.9801 - val_loss: 0.2767 - val_accuracy: 0.9837
# Epoch 21/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.2998 - accuracy: 0.9801 - val_loss: 0.2665 - val_accuracy: 0.9877
# Epoch 22/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.2848 - accuracy: 0.9831 - val_loss: 0.2619 - val_accuracy: 0.9850
# Epoch 23/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.2693 - accuracy: 0.9863 - val_loss: 0.2510 - val_accuracy: 0.9891
# Epoch 24/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.2756 - accuracy: 0.9806 - val_loss: 0.2417 - val_accuracy: 0.9918
# Epoch 25/30
# 115/115 [==============================] - 1s 13ms/step - loss: 0.2873 - accuracy: 0.9803 - val_loss: 0.2466 - val_accuracy: 0.9905
# Epoch 26/30
# 115/115 [==============================] - 1s 13ms/step - loss: 0.2842 - accuracy: 0.9779 - val_loss: 0.2538 - val_accuracy: 0.9918
# Epoch 27/30
# 115/115 [==============================] - 1s 13ms/step - loss: 0.2778 - accuracy: 0.9792 - val_loss: 0.2418 - val_accuracy: 0.9891
# Epoch 28/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.2830 - accuracy: 0.9762 - val_loss: 0.2461 - val_accuracy: 0.9918
# Epoch 29/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.2801 - accuracy: 0.9814 - val_loss: 0.2383 - val_accuracy: 0.9905
# Epoch 30/30
# 115/115 [==============================] - 1s 12ms/step - loss: 0.2675 - accuracy: 0.9825 - val_loss: 0.2351 - val_accuracy: 0.9918
# 23/23 - 0s - loss: 0.2351 - accuracy: 0.9918 - 83ms/epoch - 4ms/step
# Test accuracy: 0.9918256402015686
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Load the model
model = tf.keras.models.load_model('/content/drive/MyDrive/optimized_extracted_model_gwo_1.h5')

# Predict on validation data
y_pred = model.predict(X_val_scaled)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(val_labels, axis=1)

# Calculate accuracy, precision, recall, and F1 score
accuracy = accuracy_score(y_true_classes, y_pred_classes)
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

# Calculate the number of wrong predictions
wrong_predictions = np.sum(y_pred_classes != y_true_classes)
correct_predictions = len(y_true_classes) - wrong_predictions

# Generate the confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Print metrics
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Number of wrong predictions: {wrong_predictions}")
print(f"Confusion Matrix:\n{conf_matrix}")

# Print classification report
print("\nClassification Report:\n")
print(classification_report(y_true_classes, y_pred_classes))

# Plot the confusion matrix as an image
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Plot correct vs. wrong predictions
plt.figure(figsize=(8, 6))
plt.bar(['Correct Predictions', 'Wrong Predictions'], [correct_predictions, wrong_predictions], color=['green', 'red'])
plt.title('Correct vs Wrong Predictions')
plt.ylabel('Number of Predictions')
plt.show()
# Out:
# 23/23 [==============================] - 0s 3ms/step
# Accuracy: 0.99
# Precision: 0.99
# Recall: 0.99
# F1 Score: 0.99
# Number of wrong predictions: 6
# Confusion Matrix:
# [[361   0   0   0   0]
#  [  0  74   0   0   0]
#  [  0   1 199   0   0]
#  [  0   0   3  35   1]
#  [  0   0   1   0  59]]
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       361
#            1       0.99      1.00      0.99        74
#            2       0.98      0.99      0.99       200
#            3       1.00      0.90      0.95        39
#            4       0.98      0.98      0.98        60
#
#     accuracy                           0.99       734
#    macro avg       0.99      0.98      0.98       734
# weighted avg       0.99      0.99      0.99       734

# %%
# prompt: plot the classification report for the above model

import pandas as pd
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# !pip install seaborn
import seaborn as sns # Added this line to import the seaborn library

# Assuming y_true and y_pred are already defined

report = classification_report(y_true_classes, y_pred_classes ,output_dict=True)

# Plotting the classification report
plt.figure(figsize=(8, 6))
sns.heatmap(pd.DataFrame(report).iloc[:-1, :].T, annot=True, fmt=".2f", cmap="Blues")
plt.title("Classification Report")
plt.xlabel("Metrics")
plt.ylabel("Classes")
plt.show()

# Alternatively, you can use ConfusionMatrixDisplay for a more visual representation
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import load_model
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
import joblib



# Load the scaler
scaler = joblib.load('/content/drive/MyDrive/standard_scaler.pkl')

def extract_features(img_path, feature_extractor, target_size=(224, 224)):
    # Load and preprocess the image
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    # Preprocess the image for VGG16
    img_array = preprocess_input(img_array)

    # Extract features using the feature extractor model
    features = feature_extractor.predict(img_array)

    # Flatten the features to match the model input shape
    features_flat = features.reshape((features.shape[0], -1))

    # Scale the features using the loaded scaler
    features_scaled = scaler.transform(features_flat)

    # Select the relevant features based on the selected feature indices


    return features_scaled

def predict_single_image(model, img_path, feature_extractor):
    # Extract features from the image
    selected_features = extract_features(img_path, feature_extractor)

    # Ensure the feature shape matches what the model expects
    if selected_features.shape[1] != model.input_shape[1]:
        raise ValueError(f"Feature shape {selected_features.shape[1]} does not match model input shape {model.input_shape[1]}.")

    # Make prediction
    predictions = model.predict(selected_features)
    predicted_class = np.argmax(predictions, axis=1)

    return predicted_class

# Load the trained model
model = load_model('/content/drive/MyDrive/optimized_extracted_model_gwo_1.h5')

# Load VGG16 for feature extraction
vgg16_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Create a new model that outputs the features from the last convolutional block
feature_extractor = Model(inputs=vgg16_model.input, outputs=vgg16_model.output)

# Example usage
img_path = '/content/drive/MyDrive/dataset/preprocessed dataset/preprocessed dataset/testing/0/d1fa0f744620.png'
predicted_class = predict_single_image(model, img_path, feature_extractor)
print(f"Predicted Class: {predicted_class}")
# Out:
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 98ms/step
# Predicted Class: [0]

# %% [markdown]
# GWO WITH FEATURE SELECTION(FINAL MODEL)

# %%
# Inside your training code where you fit and transform the training features

# Fit and save the scaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(train_features)
joblib.dump(scaler, '/content/drive/MyDrive/standard_scaler.pkl')

# Transform the validation features using the fitted scaler
X_val_scaled = scaler.transform(val_features)

# %%
train_labels_flat = np.argmax(train_labels, axis=1)  # Assuming train_labels are one-hot encoded
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels_flat), y=train_labels_flat)
class_weights_dict = dict(enumerate(class_weights))

# %%
def cnn_objective_function(params):
    # Extract hyperparameters and feature selection mask
    num_neurons1 = int(params[0])
    num_neurons2 = int(params[1])
    learning_rate = params[2]
    dropout_rate = params[3]
    feature_selection_mask = params[4:]

    # Ensure feature selection mask is binary
    feature_selection_mask = np.where(feature_selection_mask >= 0.5, 1, 0)

    # Select features based on mask
    selected_features = np.where(feature_selection_mask == 1)[0]
    if len(selected_features) == 0:
        return float('inf')  # Penalize solutions with no selected features

    X_train_selected = X_train_scaled[:, selected_features]
    X_val_selected = X_val_scaled[:, selected_features]

    # Build and compile the model
    model = Sequential([
        Dense(num_neurons1, activation='relu', input_shape=(X_train_selected.shape[1],)),
        Dropout(dropout_rate),
        Dense(num_neurons2, activation='relu'),
        Dropout(dropout_rate),
        Dense(num_classes, activation='softmax')  # Output layer with num_classes neurons
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss=CategoricalCrossentropy(),
                  metrics=['accuracy'])

    # Train the model
    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    model.fit(X_train_selected, train_labels, epochs=5, batch_size=32, verbose=0, validation_data=(X_val_selected, val_labels), callbacks=[early_stopping],class_weight=class_weights_dict)

    # Evaluate the model
    val_loss, val_accuracy = model.evaluate(X_val_selected, val_labels, verbose=0)
    return -val_accuracy  # Return negative accuracy

# %%
def gwo_optimize(obj_function, num_wolves, num_iterations, dim, lower_bound, upper_bound):
    alpha_pos = np.zeros(dim)
    alpha_score = float('inf')

    beta_pos = np.zeros(dim)
    beta_score = float('inf')

    delta_pos = np.zeros(dim)
    delta_score = float('inf')

    wolves_positions = np.random.uniform(lower_bound, upper_bound, (num_wolves, dim))

    for iteration in range(num_iterations):
        for i in range(num_wolves):
            fitness = obj_function(wolves_positions[i])
            if fitness < alpha_score:
                alpha_score = fitness
                alpha_pos = wolves_positions[i].copy()
            elif fitness < beta_score:
                beta_score = fitness
                beta_pos = wolves_positions[i].copy()
            elif fitness < delta_score:
                delta_score = fitness
                delta_pos = wolves_positions[i].copy()

        a = 2 - iteration * (2 / num_iterations)

        for i in range(num_wolves):
            for j in range(dim):
                r1, r2 = np.random.rand(2)
                A1 = 2 * a * r1 - a
                C1 = 2 * r2
                D_alpha = abs(C1 * alpha_pos[j] - wolves_positions[i, j])
                X1 = alpha_pos[j] - A1 * D_alpha

                r1, r2 = np.random.rand(2)
                A2 = 2 * a * r1 - a
                C2 = 2 * r2
                D_beta = abs(C2 * beta_pos[j] - wolves_positions[i, j])
                X2 = beta_pos[j] - A2 * D_beta

                r1, r2 = np.random.rand(2)
                A3 = 2 * a * r1 - a
                C3 = 2 * r2
                D_delta = abs(C3 * delta_pos[j] - wolves_positions[i, j])
                X3 = delta_pos[j] - A3 * D_delta

                wolves_positions[i, j] = (X1 + X2 + X3) / 3
                wolves_positions[i, j] = np.clip(wolves_positions[i, j], lower_bound[j], upper_bound[j])

        print(f"Iteration {iteration+1}/{num_iterations}, Alpha Score: {-alpha_score}")

    return alpha_pos, alpha_score

# %%
num_wolves = 10
num_iterations = 20
dim = 4 + 25088  # 4 for hyperparameters and 25,088 for feature selection
lower_bound = [16, 16, 0.0001, 0.1] + [0] * 25088
upper_bound = [256, 256, 0.01, 0.5] + [1] * 25088

best_params, best_score = gwo_optimize(cnn_objective_function, num_wolves, num_iterations, dim, lower_bound, upper_bound)

# Extract the best hyperparameters
num_neurons1 = int(best_params[0])
num_neurons2 = int(best_params[1])
learning_rate = best_params[2]
dropout_rate = best_params[3]
feature_selection_mask = best_params[4:]

# Get the selected features
selected_features = np.where(feature_selection_mask >= 0.5)[0]

print(f"Best Hyperparameters:")
print(f"Number of neurons in layer 1: {num_neurons1}")
print(f"Number of neurons in layer 2: {num_neurons2}")
print(f"Learning rate: {learning_rate}")
print(f"Dropout rate: {dropout_rate}")

print(f"Number of selected features: {len(selected_features)}")
print(f"Best validation score: {-best_score}")

# Save the selected features indices
np.save('/content/drive/MyDrive/selected_feature_indices_2.npy', selected_features)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
import pickle
from tensorflow.keras.callbacks import EarlyStopping

# Assuming train_features, val_features, train_labels, and val_labels are already defined
# And that you've already selected the features as per the selected indices

# Parameters from the GWO optimization
neurons_layer1 = 181
neurons_layer2 = 150
learning_rate = 0.0004572052659916009
dropout_rate = 0.1
num_classes = 5
epochs = 25
batch_size = 32

# Feature Scaling
scaler = StandardScaler()

# Fit and transform the training features
# X_train_scaled = scaler.fit_transform(train_features)

# # Transform the validation features using the fitted scaler
# X_val_scaled = scaler.transform(val_features)

# # Save the scaler for future use
# with open('/content/drive/MyDrive/standard_scaler2.pkl', 'wb') as scaler_file:
#     pickle.dump(scaler, scaler_file)

# # Load the selected feature indices
selected_features = np.load('/content/drive/MyDrive/selected_feature_indices_2.npy')

# Define function for feature selection
def select_features(X, selected_features):
    return X[:, selected_features]

# Select features for training and validation data
X_train_selected = select_features(X_train_scaled, selected_features)
X_val_selected = select_features(X_val_scaled, selected_features)

# Build the model using the optimized parameters
# Example of adding L2 regularization and Batch Normalization

from tensorflow.keras import regularizers

model = models.Sequential([
    layers.Dense(neurons_layer1, activation='relu', input_shape=(len(selected_features),),
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Dropout(dropout_rate),
    layers.Dense(neurons_layer2, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Dropout(dropout_rate),
    layers.Dense(num_classes, activation='softmax')
])

# You can keep the rest of the training and evaluation code the same.


# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model on the selected features
history = model.fit(
    X_train_selected, train_labels,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_val_selected, val_labels),
    callbacks=[early_stopping],class_weight=class_weights_dict
)

# Evaluate the model on validation set
val_loss, val_accuracy = model.evaluate(X_val_selected, val_labels, verbose=2)
print(f"Validation accuracy: {val_accuracy}")

# Save the model
model.save('/content/drive/MyDrive/optimized_extracted_model_2.h5')

# Save the model's architecture and weights separately
model_structure = model.to_json()
model_weights = model.get_weights()

# Serialize the architecture and weights using pickle
with open('/content/drive/MyDrive/model_structure.pkl', 'wb') as file:
    pickle.dump(model_structure, file)

with open('/content/drive/MyDrive/model_weights.pkl', 'wb') as file:
    pickle.dump(model_weights, file)
import matplotlib.pyplot as plt

# Plot accuracy
plt.figure(figsize=(12, 5))

# Training and validation accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Training and validation loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save("/content/drive/MyDrive/selected_model.h5")

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
import pickle
from tensorflow.keras.callbacks import EarlyStopping

# Assuming train_features, val_features, train_labels, and val_labels are already defined
# And that you've already selected the features as per the selected indices

# Parameters from the GWO optimization
neurons_layer1 = 181
neurons_layer2 = 150
learning_rate = 0.0004572052659916009
dropout_rate = 0.1
num_classes = 5
epochs = 25
batch_size = 32

# Feature Scaling
scaler = StandardScaler()

# Fit and transform the training features
# X_train_scaled = scaler.fit_transform(train_features)

# # Transform the validation features using the fitted scaler
# X_val_scaled = scaler.transform(val_features)

# # Save the scaler for future use
# with open('/content/drive/MyDrive/standard_scaler2.pkl', 'wb') as scaler_file:
#     pickle.dump(scaler, scaler_file)

# # Load the selected feature indices
selected_features = np.load('/content/drive/MyDrive/selected_feature_indices_2.npy')

# Define function for feature selection
def select_features(X, selected_features):
    return X[:, selected_features]

# Select features for training and validation data
X_train_selected = select_features(X_train_scaled, selected_features)
X_val_selected = select_features(X_val_scaled, selected_features)

# Build the model using the optimized parameters
# Example of adding L2 regularization and Batch Normalization

from tensorflow.keras import regularizers

model = models.Sequential([
    layers.Dense(neurons_layer1, activation='relu', input_shape=(len(selected_features),),
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Dropout(dropout_rate),
    layers.Dense(neurons_layer2, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Dropout(dropout_rate),
    layers.Dense(num_classes, activation='softmax')
])

# You can keep the rest of the training and evaluation code the same.


# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model on the selected features
history = model.fit(
    X_train_selected, train_labels,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_val_selected, val_labels),
    callbacks=[early_stopping],class_weight=class_weights_dict
)

# Evaluate the model on validation set
val_loss, val_accuracy = model.evaluate(X_val_selected, val_labels, verbose=2)
print(f"Validation accuracy: {val_accuracy}")

# Save the model
model.save('/content/drive/MyDrive/optimized_extracted_model_3.h5')

# Save the model's architecture and weights separately
model_structure = model.to_json()
model_weights = model.get_weights()

# Serialize the architecture and weights using pickle
with open('/content/drive/MyDrive/model_structure.pkl', 'wb') as file:
    pickle.dump(model_structure, file)

with open('/content/drive/MyDrive/model_weights.pkl', 'wb') as file:
    pickle.dump(model_weights, file)
import matplotlib.pyplot as plt

# Plot accuracy
plt.figure(figsize=(12, 5))

# Training and validation accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Training and validation loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import load_model
import numpy as np
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the model
model = load_model('/content/drive/MyDrive/optimized_extracted_model_2.h5')

# Load selected features indices
selected_features = np.load('/content/drive/MyDrive/selected_feature_indices_2.npy')
print(f"Number of selected features: {len(selected_features)}")

# Function to select features based on indices
def select_features(X, selected_features):
    return X[:, selected_features]

# Assuming X_val_scaled is already loaded and scaled
# Select features for validation data
X_val_selected = select_features(X_val_scaled, selected_features)

# Predict using the selected features
predictions = model.predict(X_val_selected)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(val_labels, axis=1)

# Calculate overall accuracy
accuracy = accuracy_score(true_labels, predicted_labels)
print(f"Prediction Accuracy: {accuracy}")

# Calculate precision, recall, and F1 score
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
f1 = f1_score(true_labels, predicted_labels, average='weighted')

print(f"\nOverall Precision: {precision}")
print(f"Overall Recall: {recall}")
print(f"Overall F1 Score: {f1}")

# Print classification report
report = classification_report(true_labels, predicted_labels, output_dict=True)
df_report = pd.DataFrame(report).transpose()

# Generate classification report as an image
plt.figure(figsize=(10, 5))
plt.axis('off')
tbl = plt.table(cellText=df_report.values, colLabels=df_report.columns, rowLabels=df_report.index, cellLoc='center', loc='center')
tbl.scale(1.2, 1.2)
plt.title("Classification Report", fontsize=14)
plt.savefig('classification_report.png', bbox_inches='tight', dpi=300)
plt.show()

# Print confusion matrix as an array
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print("\nConfusion Matrix (Array Format):")
print(conf_matrix)

# Plot the confusion matrix as an image
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.savefig('confusion_matrix.png', bbox_inches='tight', dpi=300)
plt.show()

# Calculate the number of correct and incorrect predictions
correct_predictions = np.where(predicted_labels == true_labels)[0]
incorrect_predictions = np.where(predicted_labels != true_labels)[0]

num_correct = len(correct_predictions)
num_incorrect = len(incorrect_predictions)

# Print the number of correct and incorrect predictions
print(f"\nNumber of Correct Predictions: {num_correct}")
print(f"Number of Incorrect Predictions: {num_incorrect}")

# Create a bar plot to compare correct and incorrect predictions
plt.figure(figsize=(7, 5))
labels = ['Correct Predictions', 'Incorrect Predictions']
counts = [num_correct, num_incorrect]

plt.bar(labels, counts, color=['green', 'red'])
plt.title('Comparison of Correct and Incorrect Predictions')
plt.ylabel('Number of Predictions')
plt.savefig('correct_vs_incorrect_predictions.png', bbox_inches='tight', dpi=300)
plt.show()

# Optionally, you can inspect the first few incorrect predictions
print(f"\nFirst 5 Incorrect Predictions:")
for i in incorrect_predictions[:5]:
    print(f"Index: {i}, Predicted: {predicted_labels[i]}, True: {true_labels[i]}")

# %% [markdown]
# ACO

# %%
def aco_objective_function(params):
    # Extract hyperparameters
    num_neurons1 = int(params[0])
    num_neurons2 = int(params[1])
    learning_rate = params[2]
    dropout_rate = np.clip(params[3], 0.0, 0.99)  # Ensure dropout rate is within valid range [0, 1)

    # Feature selection part
    feature_mask = params[4:]  # Remaining part of params represents feature inclusion/exclusion
    selected_features = np.where(np.array(feature_mask) >= 0.5, True, False)  # Threshold to select features

    X_train_selected = X_train_scaled[:, selected_features]  # Select only the features chosen by the mask
    X_val_selected = X_val_scaled[:, selected_features]

    # Build and compile the model
    model = Sequential([
        Dense(num_neurons1, activation='relu', input_shape=(X_train_selected.shape[1],)),
        Dropout(dropout_rate),
        Dense(num_neurons2, activation='relu'),
        Dropout(dropout_rate),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss=CategoricalCrossentropy(),
                  metrics=['accuracy'])

    # Train the model
    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    model.fit(X_train_selected, train_labels, epochs=5, batch_size=32, verbose=0,
              validation_data=(X_val_selected, val_labels), callbacks=[early_stopping],
              class_weight=class_weights_dict)

    # Evaluate the model
    val_loss, val_accuracy = model.evaluate(X_val_selected, val_labels, verbose=0)
    return -val_accuracy  # Return negative accuracy as we're minimizing

# %%
def aco_optimize(obj_function, num_ants, num_iterations, dim, lower_bound, upper_bound, num_features, evaporation_rate=0.5, alpha=1.0, beta=1.0):
    pheromones = np.ones((dim + num_features, 2))  # 2 columns, one for each possible choice (0 or 1)
    heuristic = np.ones((dim + num_features, 2))

    best_solution = None
    best_score = float('inf')

    for iteration in range(num_iterations):
        all_solutions = []
        all_scores = []

        for ant in range(num_ants):
            solution = []
            feature_selection = []

            # Hyperparameter selection
            for i in range(dim):
                probabilities = pheromones[i] ** alpha * heuristic[i] ** beta
                probabilities = np.clip(probabilities, 1e-10, None)
                probabilities_sum = probabilities.sum()

                if probabilities_sum > 0:
                    probabilities /= probabilities_sum
                else:
                    probabilities = np.ones(2) / 2

                choice = np.random.choice([0, 1], p=probabilities)  # Choose between 0 and 1
                param_value = np.random.uniform(lower_bound[i], upper_bound[i])
                solution.append(param_value)

            # Feature selection
            for j in range(num_features):
                probabilities = pheromones[dim + j] ** alpha * heuristic[dim + j] ** beta
                probabilities = np.clip(probabilities, 1e-10, None)
                probabilities_sum = probabilities.sum()

                if probabilities_sum > 0:
                    probabilities /= probabilities_sum
                else:
                    probabilities = np.ones(2) / 2

                feature_choice = np.random.choice([0, 1], p=probabilities)
                feature_selection.append(feature_choice)

            complete_solution = solution + feature_selection
            score = obj_function(complete_solution)
            all_solutions.append(complete_solution)
            all_scores.append(score)

            if score < best_score:
                best_score = score
                best_solution = complete_solution

        # Update pheromones
        for i in range(dim + num_features):
            pheromones[i] *= (1 - evaporation_rate)
            for ant in range(num_ants):
                param_choice = int(all_solutions[ant][i] >= 0.5)  # Choose between 0 and 1

                if param_choice < pheromones.shape[1]:  # Ensure we're within bounds
                    pheromones[i, param_choice] += 1 / (all_scores[ant] + 1e-10)

        print(f"Iteration {iteration+1}/{num_iterations}, Best Score: {-best_score}")

    return best_solution, best_score

# %%
import pickle
num_ants = 10
num_iterations = 20
dim = 4  # Number of hyperparameters
num_features = X_train_scaled.shape[1]  # Number of features to select from
lower_bound = [16, 16, 0.0001, 0.0]  # Hyperparameters lower bounds
upper_bound = [256, 256, 0.01, 1.0]  # Hyperparameters upper bounds

# Run ACO optimization
best_params, best_score = aco_optimize(
    aco_objective_function,
    num_ants,
    num_iterations,
    dim,
    lower_bound,
    upper_bound,
    num_features
)

# Extract the best hyperparameters and feature mask
num_neurons1 = int(best_params[0])
num_neurons2 = int(best_params[1])
learning_rate = best_params[2]
dropout_rate = best_params[3]
feature_mask = best_params[4:]  # The remaining parameters are the feature mask

selected_feature_indices = np.where(np.array(feature_mask) >= 0.5)[0]  # Indices of selected features

print(f"Best Hyperparameters:")
print(f"Number of neurons in layer 1: {num_neurons1}")
print(f"Number of neurons in layer 2: {num_neurons2}")
print(f"Learning rate: {learning_rate}")
print(f"Dropout rate: {dropout_rate}")
print(f"Selected features: {selected_feature_indices}")  # Indices of selected features
print(f"Number of selected features: {len(selected_feature_indices)}")  # Print the number of selected features

print(f"Best validation score: {-best_score}")

# Save the selected features to a file
with open('/content/drive/MyDrive/selected_features.pkl', 'wb') as file:
    pickle.dump(selected_feature_indices, file)

print("Selected features saved successfully!")
# Out:
# Iteration 1/20, Best Score: 0.9809264540672302
# Iteration 2/20, Best Score: 0.9809264540672302
# Iteration 3/20, Best Score: 0.9809264540672302
# Iteration 4/20, Best Score: 0.9809264540672302
# Iteration 5/20, Best Score: 0.9809264540672302
# Iteration 6/20, Best Score: 0.9809264540672302
# Iteration 7/20, Best Score: 0.9809264540672302
# Iteration 8/20, Best Score: 0.9809264540672302
# Iteration 9/20, Best Score: 0.9809264540672302
# Iteration 10/20, Best Score: 0.9809264540672302
# Iteration 11/20, Best Score: 0.9809264540672302
# Iteration 12/20, Best Score: 0.9863760471343994
# Iteration 13/20, Best Score: 0.9863760471343994
# Iteration 14/20, Best Score: 0.9863760471343994
# Iteration 15/20, Best Score: 0.9863760471343994
# Iteration 16/20, Best Score: 0.9863760471343994
# Iteration 17/20, Best Score: 0.9863760471343994
# Iteration 18/20, Best Score: 0.9863760471343994
# Iteration 19/20, Best Score: 0.9863760471343994
# Iteration 20/20, Best Score: 0.9863760471343994
# Best Hyperparameters:
# Number of neurons in layer 1: 133
# Number of neurons in layer 2: 205
# Learning rate: 0.0003106752334611529
# Dropout rate: 0.0752023238067
# Selected features: [    1     2     4 ... 25085 25086 25087]
# Number of selected features: 12525
# Best validation score: 0.9863760471343994
# Selected features saved successfully!

# %%
# Iteration 1/20, Best Score: 0.9809264540672302
# Iteration 2/20, Best Score: 0.9809264540672302
# Iteration 3/20, Best Score: 0.9809264540672302
# Iteration 4/20, Best Score: 0.9809264540672302
# Iteration 5/20, Best Score: 0.9809264540672302
# Iteration 6/20, Best Score: 0.9809264540672302
# Iteration 7/20, Best Score: 0.9809264540672302
# Iteration 8/20, Best Score: 0.9809264540672302
# Iteration 9/20, Best Score: 0.9809264540672302
# Iteration 10/20, Best Score: 0.9809264540672302
# Iteration 11/20, Best Score: 0.9809264540672302
# Iteration 12/20, Best Score: 0.9863760471343994
# Iteration 13/20, Best Score: 0.9863760471343994
# Iteration 14/20, Best Score: 0.9863760471343994
# Iteration 15/20, Best Score: 0.9863760471343994
# Iteration 16/20, Best Score: 0.9863760471343994
# Iteration 17/20, Best Score: 0.9863760471343994
# Iteration 18/20, Best Score: 0.9863760471343994
# Iteration 19/20, Best Score: 0.9863760471343994
# Iteration 20/20, Best Score: 0.9863760471343994
# Best Hyperparameters:
# Number of neurons in layer 1: 133
# Number of neurons in layer 2: 205
# Learning rate: 0.0003106752334611529
# Dropout rate: 0.0752023238067
# Selected features: [    1     2     4 ... 25085 25086 25087]
# Number of selected features: 12525
# Best validation score: 0.9863760471343994
# Selected features saved successfully!

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
import pickle
import matplotlib.pyplot as plt

# Assuming train_features, val_features, train_labels, and val_labels are already defined

# Parameters from the ACO optimization
learning_rate = 0.0003106752334611529
dropout_rate = 0.0752023238067
neurons_layer1 = 133
neurons_layer2 = 205
num_classes = 5
epochs = 25
batch_size = 32

# Extract selected feature indices from ACO optimization
# Assuming `best_params` is the output from your ACO optimization code
feature_mask = best_params[4:]  # The remaining parameters are the feature mask
selected_feature_indices = np.where(np.array(feature_mask) >= 0.5)[0]  # Indices of selected features

# Save the selected feature indices
with open('/content/drive/MyDrive/selected_feature_indices.pkl', 'wb') as f:
    pickle.dump(selected_feature_indices, f)

# Load selected features
X_train_scaled1 = X_train_scaled[:, selected_feature_indices]
X_val_scaled1 = X_val_scaled[:, selected_feature_indices]

# Feature Scaling
scaler = StandardScaler()


# Save the scaler using joblib or pickle
with open('/content/drive/MyDrive/standard_scaler.pkl', 'wb') as scaler_file:
    pickle.dump(scaler, scaler_file)

# Build the model to train on extracted features
model = models.Sequential()
model.add(layers.Input(shape=(X_train_scaled1.shape[1],)))
model.add(layers.Dense(neurons_layer1, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(dropout_rate))  # Use optimized dropout rate
model.add(layers.Dense(neurons_layer2, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(dropout_rate))  # Use optimized dropout rate
model.add(layers.Dense(num_classes, activation='softmax'))

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model on scaled features
history = model.fit(
    X_train_scaled1, train_labels,
    epochs=epochs,
    validation_data=(X_val_scaled1, val_labels),
    batch_size=batch_size
)

# Evaluate the model on validation set
test_loss, test_acc = model.evaluate(X_val_scaled1, val_labels, verbose=2)
print(f"Test accuracy: {test_acc}")

# Save the trained model
model.save('/content/drive/MyDrive/optimized_extracted_model_1.h5')

# Save the model's architecture and weights separately
model_structure = model.to_json()
model_weights = model.get_weights()

# Serialize the architecture and weights using pickle
with open('model_structure.pkl', 'wb') as file:
    pickle.dump(model_structure, file)

with open('model_weights.pkl', 'wb') as file:
    pickle.dump(model_weights, file)

# Plotting training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

# Plotting training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/25
# 115/115 [==============================] - 2s 11ms/step - loss: 1.2892 - accuracy: 0.7051 - val_loss: 0.7276 - val_accuracy: 0.8896
# Epoch 2/25
# 115/115 [==============================] - 1s 9ms/step - loss: 0.6959 - accuracy: 0.9020 - val_loss: 0.5176 - val_accuracy: 0.9755
# Epoch 3/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.5467 - accuracy: 0.9519 - val_loss: 0.4520 - val_accuracy: 0.9864
# Epoch 4/25
# 115/115 [==============================] - 1s 9ms/step - loss: 0.4821 - accuracy: 0.9730 - val_loss: 0.4251 - val_accuracy: 0.9850
# Epoch 5/25
# 115/115 [==============================] - 1s 9ms/step - loss: 0.4542 - accuracy: 0.9784 - val_loss: 0.4173 - val_accuracy: 0.9850
# Epoch 6/25
# 115/115 [==============================] - 1s 9ms/step - loss: 0.4410 - accuracy: 0.9773 - val_loss: 0.3851 - val_accuracy: 0.9905
# Epoch 7/25
# 115/115 [==============================] - 1s 9ms/step - loss: 0.4184 - accuracy: 0.9817 - val_loss: 0.3889 - val_accuracy: 0.9850
# Epoch 8/25
# 115/115 [==============================] - 1s 9ms/step - loss: 0.4008 - accuracy: 0.9844 - val_loss: 0.3678 - val_accuracy: 0.9877
# Epoch 9/25
# 115/115 [==============================] - 1s 9ms/step - loss: 0.3921 - accuracy: 0.9831 - val_loss: 0.3573 - val_accuracy: 0.9850
# Epoch 10/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.3777 - accuracy: 0.9847 - val_loss: 0.3471 - val_accuracy: 0.9946
# Epoch 11/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.3785 - accuracy: 0.9803 - val_loss: 0.3329 - val_accuracy: 0.9891
# Epoch 12/25
# 115/115 [==============================] - 1s 9ms/step - loss: 0.3658 - accuracy: 0.9847 - val_loss: 0.3294 - val_accuracy: 0.9905
# Epoch 13/25
# 115/115 [==============================] - 1s 9ms/step - loss: 0.3677 - accuracy: 0.9784 - val_loss: 0.3221 - val_accuracy: 0.9932
# Epoch 14/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.3493 - accuracy: 0.9809 - val_loss: 0.3097 - val_accuracy: 0.9918
# Epoch 15/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.3494 - accuracy: 0.9817 - val_loss: 0.3156 - val_accuracy: 0.9877
# Epoch 16/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.3380 - accuracy: 0.9839 - val_loss: 0.2998 - val_accuracy: 0.9891
# Epoch 17/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.3301 - accuracy: 0.9814 - val_loss: 0.2970 - val_accuracy: 0.9877
# Epoch 18/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.3257 - accuracy: 0.9798 - val_loss: 0.2939 - val_accuracy: 0.9877
# Epoch 19/25
# 115/115 [==============================] - 1s 9ms/step - loss: 0.3231 - accuracy: 0.9820 - val_loss: 0.2827 - val_accuracy: 0.9905
# Epoch 20/25
# 115/115 [==============================] - 1s 9ms/step - loss: 0.3127 - accuracy: 0.9839 - val_loss: 0.2772 - val_accuracy: 0.9891
# Epoch 21/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.3014 - accuracy: 0.9801 - val_loss: 0.2827 - val_accuracy: 0.9850
# Epoch 22/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.2981 - accuracy: 0.9825 - val_loss: 0.2675 - val_accuracy: 0.9877
# Epoch 23/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.2963 - accuracy: 0.9825 - val_loss: 0.2594 - val_accuracy: 0.9891
# Epoch 24/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.2790 - accuracy: 0.9833 - val_loss: 0.2498 - val_accuracy: 0.9905
# Epoch 25/25
# 115/115 [==============================] - 1s 8ms/step - loss: 0.2808 - accuracy: 0.9803 - val_loss: 0.2417 - val_accuracy: 0.9946
# 23/23 - 0s - loss: 0.2417 - accuracy: 0.9946 - 72ms/epoch - 3ms/step
# Test accuracy: 0.9945504069328308
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.models import load_model
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# Load the model
model = load_model('/content/drive/MyDrive/optimized_extracted_model_1.h5')

# Load selected features indices
selected_features = np.load('/content/drive/MyDrive/selected_feature_indices.pkl', allow_pickle=True)
print(f"Number of selected features: {len(selected_features)}")

# Function to select features based on indices
def select_features(X, selected_features):
    return X[:, selected_features]

# Assuming X_val_scaled is already loaded and scaled
# Select features for validation data
X_val_selected = select_features(X_val_scaled, selected_features)

# Predict using the selected features
predictions = model.predict(X_val_selected)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(val_labels, axis=1)

# Calculate overall accuracy
accuracy = accuracy_score(true_labels, predicted_labels)
print(f"Prediction Accuracy: {accuracy}")

# Calculate precision, recall, and F1 score
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
f1 = f1_score(true_labels, predicted_labels, average='weighted')

print(f"\nOverall Precision: {precision}")
print(f"Overall Recall: {recall}")
print(f"Overall F1 Score: {f1}")

# Print classification report
report = classification_report(true_labels, predicted_labels, output_dict=True)
report_df = pd.DataFrame(report).transpose()
print("\nClassification Report:")
print(report_df)

# Print confusion matrix as an array
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print("\nConfusion Matrix (Array Format):")
print(conf_matrix)

# Convert confusion matrix to DataFrame for better visualization
conf_matrix_df = pd.DataFrame(conf_matrix, index=[f"True {i}" for i in range(conf_matrix.shape[0])],
                              columns=[f"Predicted {i}" for i in range(conf_matrix.shape[1])])
print("\nConfusion Matrix (Table Format):")
print(conf_matrix_df)

# Plot the confusion matrix as an image
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Calculate the number of correct and incorrect predictions
correct_predictions = np.where(predicted_labels == true_labels)[0]
incorrect_predictions = np.where(predicted_labels != true_labels)[0]

num_correct = len(correct_predictions)
num_incorrect = len(incorrect_predictions)

# Print the number of correct and incorrect predictions
print(f"\nNumber of Correct Predictions: {num_correct}")
print(f"Number of Incorrect Predictions: {num_incorrect}")

# Create a bar plot to compare correct and incorrect predictions
plt.figure(figsize=(7, 5))
labels = ['Correct Predictions', 'Incorrect Predictions']
counts = [num_correct, num_incorrect]

plt.bar(labels, counts, color=['green', 'red'])
plt.title('Comparison of Correct and Incorrect Predictions')
plt.ylabel('Number of Predictions')
plt.show()

# Optionally, you can inspect the first few incorrect predictions
print(f"\nFirst 5 Incorrect Predictions:")
for i in incorrect_predictions[:5]:
    print(f"Index: {i}, Predicted: {predicted_labels[i]}, True: {true_labels[i]}")
# Out:
# Number of selected features: 12525
# 23/23 [==============================] - 0s 2ms/step
# Prediction Accuracy: 0.9945504087193461
#
# Overall Precision: 0.9946298476944211
# Overall Recall: 0.9945504087193461
# Overall F1 Score: 0.9945700026802474
#
# Classification Report:
#               precision    recall  f1-score    support
# 0              1.000000  1.000000  1.000000  361.00000
# 1              0.986667  1.000000  0.993289   74.00000
# 2              0.994975  0.990000  0.992481  200.00000
# 3              0.950000  0.974359  0.962025   39.00000
# 4              1.000000  0.983333  0.991597   60.00000
# accuracy       0.994550  0.994550  0.994550    0.99455
# macro avg      0.986328  0.989538  0.987878  734.00000
# weighted avg   0.994630  0.994550  0.994570  734.00000
#
# Confusion Matrix (Array Format):
# [[361   0   0   0   0]
#  [  0  74   0   0   0]
#  [  0   1 198   1   0]
#  [  0   0   1  38   0]
#  [  0   0   0   1  59]]
#
# Confusion Matrix (Table Format):
#         Predicted 0  Predicted 1  Predicted 2  Predicted 3  Predicted 4
# True 0          361            0            0            0            0
# True 1            0           74            0            0            0
# True 2            0            1          198            1            0
# True 3            0            0            1           38            0
# True 4            0            0            0            1           59
# Number of Correct Predictions: 730
# Number of Incorrect Predictions: 4
# First 5 Incorrect Predictions:
# Index: 530, Predicted: 1, True: 2
# Index: 594, Predicted: 3, True: 2
# Index: 640, Predicted: 2, True: 3
# Index: 718, Predicted: 3, True: 4

# %%
# prompt: plot the classification report for the above model

import pandas as pd
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# !pip install seaborn
import seaborn as sns # Added this line to import the seaborn library

# Assuming y_true and y_pred are already defined

report = classification_report(true_labels, predicted_labels, output_dict=True)

# Plotting the classification report
plt.figure(figsize=(8, 6))
sns.heatmap(pd.DataFrame(report).iloc[:-1, :].T, annot=True, fmt=".2f", cmap="Blues")
plt.title("Classification Report")
plt.xlabel("Metrics")
plt.ylabel("Classes")
plt.show()

# Alternatively, you can use ConfusionMatrixDisplay for a more visual representation
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
